# %% [markdown]
# # Python  lecture notes

# %% [markdown]
# ## Variables

# %%
name : str = "                   fatima          naeem    "

name
# Out:
# '                   fatima          naeem    '

# %%
name = "     Fatima      Naeem     "
' '.join(name.split())
# Out:
# 'Fatima Naeem'

# %%
names = ['fatima' , 'tehreem']
for name , index in enumerate(names):
     print(name , index)
# Out:
# 0 fatima
# 1 tehreem

# %%
names = ['fatima' , 'tehreem']
for name in names:
     print(list(enumerate(name)))
# Out:
# [(0, 'f'), (1, 'a'), (2, 't'), (3, 'i'), (4, 'm'), (5, 'a')]
# [(0, 't'), (1, 'e'), (2, 'h'), (3, 'r'), (4, 'e'), (5, 'e'), (6, 'm')]

# %%
[i for i in dir(name) if '__' not in i]
# Out:
# ['capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# string data type

# %%
name : str = "Fatima"
# "" , ' ' , """  """
print(type(name))
print(name)

# %%
message = "PIAIC student card \n father's name"
print(message)

# %%
message = 'PIAIC student card \n father\'s name'
print(message)
# Out:
# PIAIC student card
#  father's name

# %%
name = "Fatima"
fname = "naeem"
age = 16
education = "matric pass"
card = "My name is " + name + " \n and my fathers name is \n" + fname 
print(card)

# %%
name = "Fatima"
fname = "naeem"
age = 16
age = str(age)
education = "matric pass"
card = "My name is\n " + name + " \nand my fathers name is\n" + fname + "and her age is\n" + age
print(card)
# Out:
# My name is
#  Fatima
# and my fathers name is
# naeemand her age is
# 16

# %%
# / means line continue 

print(1+ \
      4+ \
      8)
# Out:
# 13

# %% [markdown]
# F string

# %%
name = "Fatima"
fname = "naeem"
age = 16
education = "matric pass"

card = f"""
STudents card:{name}
Father name:{fname}
education:{education}
total {1+33+5}

"""
print(card)

# %%
#backticks cause error
name = "Fatima"
fname = "naeem"
age = 16
education = "matric pass"
#only use three ticks
card = f' 
STudents card:{name}
Father name:{fname}
education:{education}
'

print(card)
# Out:
#   Cell In[4], line 7
#     card = f'
#            ^
# SyntaxError: unterminated f-string literal (detected at line 7)

# %%
name = "fatima"
name = f"MY name is {name}" #f_string
print(name)
name = "fatima"
name = f"""MY name is {{name}}"""
print(name)
# Out:
# MY name is fatima
# MY name is {name}

# %%
[i for i in dir (str) if "__" not in i]

# %%
name = "FaTiMa"
print(name.capitalize())
print(name.lower())
print(name.upper())
a = 2
b = 5
formatted_string = "The value of a = {} and b = {}".format(a, b)
print(formatted_string)
# Out:
# Fatima
# fatima
# FATIMA
# The value of a = 2 and b = 5

# %%
a = "   fatima      "
print(a.casefold())
print(a.lower())
print(a.strip())
print(a.rstrip())
print(a.lstrip())
print(a)
# Out:
#    fatima
#    fatima
# fatima
#    fatima
# fatima
#    fatima

# %%
name = "Fatima"
fname = "naeem"
age = 16
education = "matric pass"

card = """
STudents card:{}
Father name:{}
education:{}


""".format(name , fname , education)
print(card)

# %%
name = "Fatima"
fname = "naeem"
age = 16
education = "matric pass"

card = """
STudents card:{1}
Father name:{0}
education:{2}


""".format( fname , name, education)
print(card)
# Out:
# STudents card:Fatima
# Father name:naeem
# education:matric pass

# %%
student = """
print("My name is Fatima")
a = 2
v = 5
print(a + v)
"""
exec(student)
print(student)
# Out:
# My name is Fatima
# 7
#
# print("My name is Fatima")
# a = 2
# v = 5
# print(a + v)

# %%
print("hello\nworld")
print("hello\tworld")
print("hello\bworld")
# Out:
# hello
# world
# hello	world
# hellworld

# %%
url = "http://google.classroom.com/"
print(url.removeprefix("http://"))
print(url.removesuffix(".com/"))

# %%
alphabets : list = list('ABCDEFGHI')
print(alphabets)
# print(alphabets[-2, -4])
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']

# %%
test : list[str] = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
print(test[-5: -3])
# Out:
# ['E', 'F']
