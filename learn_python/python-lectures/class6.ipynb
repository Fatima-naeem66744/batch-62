# %% [markdown]
# # if else statement

# %%
if False:
    print("pakistan")
else:
    print("hello world")
# Out:
# hello world

# %% [markdown]
# ## comprehensive style

# %%
print("pakistan") if False else print("hello world")
# Out:
# hello world

# %%
if True:
    print("pakistan")
elif True:
    print("fatima")
# Out:
# pakistan

# %%
if False:
    print("pakistan")
print("1")
# Out:
# 1

# %%
if True:
    print("true block")
else:
    print("final block")

# %%
if False:
    print("true block")
elif True:
    print("elif logic 1")
else:
    print("final block")
# Out:
# elif logic 1

# %%
from typing import Union
per : Union[float,int] = int(input("write your percentage:"))
grade : Union[float,None] = None 
if per >= 80:
    grade = "A"
elif per >=70:
    grade = "B"
elif per >= 50:
    grade = "C"
else:
    grade = "fail"
print(f"your grade is {grade}")
# Out:
# your grade is fail

# %%
from typing import Union
per : Union[float,int] = int(input("write your percentage:"))
grade : Union[float,None] = None 
if per >= 0:  #logical error
    grade = "fail"
elif per >=40:
    grade = "B"
elif per >= 50:
    grade = "C"
else:
    grade = "fail"
print(f"your grade is {grade}")
# Out:
# your grade is fail

# %%
from typing import Union

pertype = Union[float, int]
grades = []
percentage: list[pertype] = [88, 99.9, 70]

for per in percentage:
    grade = ""
    if 0 <= per < 30:
        grade = "F"
    elif 30 <= per < 50:
        grade = "C"
    elif 50 <= per < 70:
        grade = "B"
    elif 70 <= per < 90:
        grade = "A"
    elif per >= 90:
        grade = "A+"
    grades.append(grade)

print(percentage)
print(grades)
list(zip(percentage , grades , enumerate(percentage) ))
# Out:
# [88, 99.9, 70]
# ['A', 'A+', 'A']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 23
#      21 print(percentage)
#      22 print(grades)
# ---> 23 list(zip(percentage , grades , enumerate(percentage) ))
#
# TypeError: 'zip' object is not callable

# %%
list(zip(percentage, grades , list(range(len(percentage)))))
# Out:
# [(88, 'A', 0), (99.9, 'A+', 1), (70, 'A', 2)]

# %%
roll_no =  list(range(len(percentage)))
result = list(zip(roll_no , grades , percentage))
# Out:
# [(0, 'A', 88), (1, 'A+', 99.9), (2, 'A', 70)]

# %%
roll = ["1"]
grades = ["A"]
result = list(zip(roll, grades))
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 roll = ["1"]
#       2 grades = ["A"]
# ----> 3 result = list(zip(roll, grades))
#       4 result
#
# TypeError: 'zip' object is not callable

# %%
sorted(result , key= lambda x:x[2] , reverse=True)
# Out:
# [(1, 'A+', 99.9), (0, 'A', 88), (2, 'A', 70)]

# %%
cars = ["bmw" , "mercEdes"]
for car in cars:
  if car == "bmw":
    print(car.upper())
  else:
    print(car.lower())
# Out:
# BMW
# mercedes

# %%
car = ["bmw", "mercEdes"]
result = [i.title() if i == "bmw" else i.lower() for i in car]
print(result)
# Out:
# ['Bmw', 'mercedes']

# %%
car = "mercedes"
if car == "Audi":
  print(car.capitalize())
else:
  print(car.upper())
# Out:
# MERCEDES

# %%
person = ["ali" , "ahmad"]
user = "ahmad"
if user  in person:
   print("hello")
# Out:
# hello

# %%
requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']
for requested_topping in requested_toppings:
 print(f"Adding {requested_topping}.")
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Adding green peppers.
# Adding extra cheese.
#
# Finished making your pizza!

# %%
user_name = input("write the user name:")
user_pass = input("write the user password:")
if user_name == "admin" and user_pass == "admin":
  print("plz enter the OTP")
OTP = input("plz enter the otp")
if OTP == "123":  
   print("Welcome PIAIC")
else:
   print("invalid person")
# Out:
# Welcome PIAIC
